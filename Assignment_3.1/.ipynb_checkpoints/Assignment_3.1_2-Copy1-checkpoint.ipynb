# %% [markdown]
# # Linear Regression By Gradient Descent

# %% [markdown]
# ### Importing Libraries

# %%
import pandas as pd
import numpy as np
import os
import random
import matplotlib.pyplot as plt
import seaborn as sn
# %matplotlib inline

# %%
os.getcwd()
# %ls
# Out:
#  Volume in drive C is OS
#  Volume Serial Number is 7CC1-D156
#
#  Directory of C:\Users\Asus\Documents\DSc_Assignment\Assignment_3.1
#
# 01/31/2022  03:34 PM    <DIR>          .
# 01/31/2022  10:09 AM    <DIR>          ..
# 01/31/2022  11:48 AM    <DIR>          .ipynb_checkpoints
# 01/31/2022  12:00 PM            65,210 Assignment_3.1_1.ipynb
# 01/31/2022  03:34 PM            80,294 Assignment_3.1_2.ipynb
# 01/31/2022  11:53 AM            49,082 housing.csv
# 01/31/2022  10:13 AM               454 Salary_Data.csv
#                4 File(s)        195,040 bytes
#                3 Dir(s)  41,252,687,872 bytes free

# %% [markdown]
# ### Importing dataset

# %%
column_names = ['CRIM', 'ZN', 'INDUS', 'CHAS', 'NOX', 'RM', 'AGE', 'DIS', 'RAD', 'TAX', 'PTRATIO', 'B', 'LSTAT', 'MEDV']
dataset = pd.read_csv('housing.csv', header=None, delimiter=r"\s+", names=column_names)
dataset = dataset.sample(frac=1).reset_index(drop=True)
dataset.head(10)
# Out:
#       CRIM    ZN  INDUS  CHAS     NOX     RM   AGE     DIS  RAD    TAX  \
# 0  0.08014   0.0   5.96     0  0.4990  5.850  41.5  3.9342    5  279.0
# 1  0.52058   0.0   6.20     1  0.5070  6.631  76.5  4.1480    8  307.0
# 2  0.01538  90.0   3.75     0  0.3940  7.454  34.2  6.3361    3  244.0
# 3  0.21038  20.0   3.33     0  0.4429  6.812  32.2  4.1007    5  216.0
# 4  3.84970   0.0  18.10     1  0.7700  6.395  91.0  2.5052   24  666.0
# 5  2.92400   0.0  19.58     0  0.6050  6.101  93.0  2.2834    5  403.0
# 6  0.31827   0.0   9.90     0  0.5440  5.914  83.2  3.9986    4  304.0
# 7  8.26725   0.0  18.10     1  0.6680  5.875  89.6  1.1296   24  666.0
# 8  1.25179   0.0   8.14     0  0.5380  5.570  98.1  3.7979    4  307.0
# 9  0.12932   0.0  13.92     0  0.4370  6.678  31.1  5.9604    4  289.0
#
#    PTRATIO       B  LSTAT  MEDV
# 0     19.2  396.90   8.77  21.0
# 1     17.4  388.45   9.54  25.1
# 2     15.9  386.34   3.11  44.0
# 3     14.9  396.90   4.85  35.1
# 4     20.2  391.34  13.27  21.7
# 5     14.7  240.16   9.81  25.0
# 6     18.4  390.70  18.33  17.8
# 7     20.2  347.88   8.88  50.0
# 8     21.0  376.57  21.02  13.6
# 9     16.0  396.90   6.27  28.6

# %%
x = dataset.loc[:,column_names[:-1]]
x
# Out:
#          CRIM    ZN  INDUS  CHAS     NOX     RM   AGE     DIS  RAD    TAX  \
# 0     0.08014   0.0   5.96     0  0.4990  5.850  41.5  3.9342    5  279.0
# 1     0.52058   0.0   6.20     1  0.5070  6.631  76.5  4.1480    8  307.0
# 2     0.01538  90.0   3.75     0  0.3940  7.454  34.2  6.3361    3  244.0
# 3     0.21038  20.0   3.33     0  0.4429  6.812  32.2  4.1007    5  216.0
# 4     3.84970   0.0  18.10     1  0.7700  6.395  91.0  2.5052   24  666.0
# ..        ...   ...    ...   ...     ...    ...   ...     ...  ...    ...
# 501  15.02340   0.0  18.10     0  0.6140  5.304  97.3  2.1007   24  666.0
# 502   0.08308   0.0   2.46     0  0.4880  5.604  89.8  2.9879    3  193.0
# 503   0.10959   0.0  11.93     0  0.5730  6.794  89.3  2.3889    1  273.0
# 504   0.05660   0.0   3.41     0  0.4890  7.007  86.3  3.4217    2  270.0
# 505  10.06230   0.0  18.10     0  0.5840  6.833  94.3  2.0882   24  666.0
#
#      PTRATIO       B  LSTAT
# 0       19.2  396.90   8.77
# 1       17.4  388.45   9.54
# 2       15.9  386.34   3.11
# 3       14.9  396.90   4.85
# 4       20.2  391.34  13.27
# ..       ...     ...    ...
# 501     20.2  349.48  24.91
# 502     17.8  391.00  13.98
# 503     21.0  393.45   6.48
# 504     17.8  396.90   5.50
# 505     20.2   81.33  19.69
#
# [506 rows x 13 columns]

# %% [markdown]
# ### Scaling with 0 mean and 1 standard deviation

# %%
for i in column_names[:-1]:
    x[i] = (x[i]-x[i].mean())/x[i].std()
x
# Out:
#          CRIM        ZN     INDUS      CHAS       NOX        RM       AGE  \
# 0   -0.410785 -0.487240 -0.754594 -0.272329 -0.480637 -0.618593 -0.961847
# 1   -0.359580 -0.487240 -0.719610  3.664771 -0.411598  0.492965  0.281542
# 2   -0.418314  3.371702 -1.076734 -0.272329 -1.386765  1.664300 -1.221183
# 3   -0.395643  0.370303 -1.137956 -0.272329 -0.964768  0.750573 -1.292233
# 4    0.027457 -0.487240  1.014995  3.664771  1.858036  0.157078  0.796661
# ..        ...       ...       ...       ...       ...       ...       ...
# 501  1.326491 -0.487240  1.014995 -0.272329  0.511789 -1.395688  1.020471
# 502 -0.410443 -0.487240 -1.264771 -0.272329 -0.575564 -0.968713  0.754030
# 503 -0.407361 -0.487240  0.115624 -0.272329  0.157968  0.724955  0.736268
# 504 -0.413521 -0.487240 -1.126295 -0.272329 -0.566935  1.028107  0.629692
# 505  0.749723 -0.487240  1.014995 -0.272329  0.252895  0.780461  0.913895
#
#           DIS       RAD       TAX   PTRATIO         B     LSTAT
# 0    0.066086 -0.522484 -0.766817  0.343873  0.440616 -0.543766
# 1    0.167619 -0.177944 -0.600682 -0.487557  0.348059 -0.435938
# 2    1.206746 -0.752178 -0.974487 -1.180415  0.324947 -1.336365
# 3    0.145156 -0.522484 -1.140622 -1.642320  0.440616 -1.092704
# 4   -0.612545  1.659603  1.529413  0.805778  0.379714  0.086393
# ..        ...       ...       ...       ...       ...       ...
# 501 -0.804642  1.659603  1.529413  0.805778 -0.078800  1.716403
# 502 -0.383311 -0.752178 -1.277091 -0.302794  0.375990  0.185818
# 503 -0.667776 -0.981871 -0.802418  1.175303  0.402826 -0.864446
# 504 -0.177300 -0.867024 -0.820218 -0.302794  0.440616 -1.001681
# 505 -0.810578  1.659603  1.529413  0.805778 -3.015986  0.985419
#
# [506 rows x 13 columns]

# %%
y = dataset.loc[:,column_names[-1]]
y_mean = y.mean() #for rescaling later
y_std = y.std() #for rescaling later
y = (y-y_mean)/y_std
y
# Out:
# 0     -0.166662
# 1      0.279131
# 2      2.334125
# 3      1.366429
# 4     -0.090551
#          ...
# 501   -1.145231
# 502    0.420479
# 503   -0.057932
# 504    0.116036
# 505   -0.916898
# Name: MEDV, Length: 506, dtype: float64

#  -0.59070837 -0.12316989 -0.09055093 -0.51459745 -0.99300891 -0.27539172
#  -1.56927726  0.12690883  2.9865046   0.00730596 -0.11229691 -0.26451873
#  -0.05793197  2.9865046  -0.32975666  0.82278004 -0.8299141  -0.49285148
#   0.93150992  0.43135248]

# %%
test_x = x.tail(len(x)-mark).to_numpy()
test_y = y.tail(len(y)-mark).to_numpy()
print(test_x)
print(test_y)
# Out:
# [[-0.4001727  -0.48724019 -0.61611679 ... -0.25660396  0.44061589
#   -0.34211486]
#  [-0.41056967 -0.48724019  0.40569652 ... -1.1342242   0.44061589
#   -0.31550817]
#  [-0.40677849  0.37030254 -0.60882854 ...  0.06672981  0.41936607
#   -0.68940216]
#  ...
#  [-0.40736095 -0.48724019  0.11562398 ...  1.17530274  0.40282626
#   -0.86444617]
#  [-0.41352147 -0.48724019 -1.12629463 ... -0.3027945   0.44061589
#   -1.00168066]
#  [ 0.74972303 -0.48724019  1.01499462 ...  0.80577843 -3.01598599
#    0.98541887]]
# [-0.35150264 -0.09055093  0.20301974 -0.68856526  2.08404662  1.1272237
#  -0.21015379 -0.57983538 -0.40586757  0.94238291 -0.69943824 -0.14491587
#   0.2356387   1.31206449 -1.30832556 -0.75380318 -0.78642214  2.62769601
#   1.39904839 -0.69943824  0.12690883 -1.16697672  0.02905194  0.2356387
#   0.98587486  0.20301974  2.20364948 -1.0038819  -1.63451519  2.9865046
#   0.00730596  0.00730596 -0.05793197 -0.26451873 -0.23189977  0.21389273
#  -0.34062965  0.58357431  2.31237936 -0.4711055   0.08341687 -0.44935953
#  -0.31888367 -0.42761355 -0.52547044 -0.35150264  1.18158864 -1.52578531
#  -0.00356703  0.08341687  1.67087308  0.5944473  -1.68888013  0.80103407
#   0.0616709   0.58357431  0.20301974 -0.53634343 -0.34062965 -0.94951696
#  -0.86253306 -0.31888367 -0.34062965 -0.07967794 -1.13435775 -1.41705543
#  -0.12316989 -0.27539172  0.26825767 -1.02562788 -0.28626471 -0.23189977
#   0.17040078 -0.26451873 -0.89515202 -0.14491587  0.05079791  0.12690883
#   0.39873352 -0.26451873 -1.05824684  0.1486548  -0.01444002 -0.56896239
#   0.97500187  1.34468345 -0.11229691  1.48603229 -0.05793197 -0.75380318
#   0.24651169 -0.69943824 -0.03618599 -1.90633988 -1.54753129 -0.05793197
#  -1.11261178 -1.14523074  0.42047949 -0.05793197  0.11603584 -0.916898  ]

# %% [markdown]
# ### Gradient Descent

# %%
def Vanilla_GD(wt,x, y, lr = 0.5, iter=500):
    for i in range(0,iter):
        y_pred = x@wt
        gradient = (y_pred - y)@x/len(y)
        wt = wt - lr * gradient
        if(i%10 == 0):
            loss =  np.sqrt(np.sum(np.square(y_pred-y)))
            print("Loss after iteration %d : "%i, loss)
        if(i%100 == 0):
            lr = lr/2

# %%
def SGD(wt,x, y, lr = 0.5, iter=5000):
    for i in range(0,iter):
        for j in range(0,x.shape[0]):
            y_pred = x[j,:]@wt
            grad = (y_pred - y[j])*x[j,:]/len(y)
            wt = wt - lr * gradient
#         if(i%10 == 0):
#             loss =  np.sqrt(np.sum(np.square(y_pred-y)))
#             print("Loss after iteration %d : "%i, loss)
        if(i%200 == 0):
            lr = lr/2

# %%
#initialize weight
wt = np.random.rand(train_x.shape[1]+1)
wt.shape
# Out:
# (14,)

# %%
x = np.empty((train_x.shape[0],train_x.shape[1]+1))
x.shape
x[:,0] = 1
x[:,1:] = train_x[:,:]
x

# y_pred = x@wt
# gradient = (y_pred - train_y)@x/len(y)
# gradient
# Out:
# array([[ 1.        , -0.41078475, -0.48724019, ...,  0.34387304,
#          0.44061589, -0.54376555],
#        [ 1.        , -0.35958   , -0.48724019, ..., -0.48755665,
#          0.34805866, -0.43593844],
#        [ 1.        , -0.41831363,  3.3717021 , ..., -1.18041474,
#          0.32494674, -1.3363648 ],
#        ...,
#        [ 1.        , -0.38226778, -0.48724019, ...,  1.26768382,
#          0.44061589,  0.3832675 ],
#        [ 1.        , -0.41755911,  2.085388  , ..., -1.31898635,
#          0.40194997, -1.06749721],
#        [ 1.        , -0.40681105, -0.48724019, ...,  1.1291122 ,
#          0.42615725, -0.69780427]])

# %%
Vanilla_GD(wt,x,train_y)
# SGD(wt,x,train_y)
# Out:
# Loss after iteration 0 :  52.2161155804375
# Loss after iteration 10 :  12.990845192025432
# Loss after iteration 20 :  10.991425822812603
# Loss after iteration 30 :  10.44497858799743
# Loss after iteration 40 :  10.248741864556155
# Loss after iteration 50 :  10.166261013258406
# Loss after iteration 60 :  10.127927589668136
# Loss after iteration 70 :  10.108479699096428
# Loss after iteration 80 :  10.097714381262257
# Loss after iteration 90 :  10.091250795879445
# Loss after iteration 100 :  10.087102058531512
# Loss after iteration 110 :  10.08544176996305
# Loss after iteration 120 :  10.084201719086721
# Loss after iteration 130 :  10.08316493786839
# Loss after iteration 140 :  10.082293562601574
# Loss after iteration 150 :  10.081558209242711
# Loss after iteration 160 :  10.080935678966954
# Loss after iteration 170 :  10.080407376170418
# Loss after iteration 180 :  10.079958199952243
# Loss after iteration 190 :  10.079575753327802
# Loss after iteration 200 :  10.079249768145223
# Loss after iteration 210 :  10.079091625770214
# Loss after iteration 220 :  10.078959375712765
# Loss after iteration 230 :  10.0788371660931
# Loss after iteration 240 :  10.078724220723164
# Loss after iteration 250 :  10.078619826095167
# Loss after iteration 260 :  10.07852332581375
# Loss after iteration 270 :  10.078434115614565
# Loss after iteration 280 :  10.078351638892318
# Loss after iteration 290 :  10.078275382673555
# Loss after iteration 300 :  10.078204873979496
# Loss after iteration 310 :  10.07816841319952
# Loss after iteration 320 :  10.078136606760776
# Loss after iteration 330 :  10.078106019873307
# Loss after iteration 340 :  10.078076605507603
# Loss after iteration 350 :  10.07804831847503
# Loss after iteration 360 :  10.078021115353014
# Loss after iteration 370 :  10.077994954413537
# Loss after iteration 380 :  10.077969795554786
# Loss after iteration 390 :  10.077945600235768
# Loss after iteration 400 :  10.077922331413761
# Loss after iteration 410 :  10.077909920428286
# Loss after iteration 420 :  10.077898867506704
# Loss after iteration 430 :  10.077888028107532
# Loss after iteration 440 :  10.077877398092689
# Loss after iteration 450 :  10.077866973404976
# Loss after iteration 460 :  10.077856750066466
# Loss after iteration 470 :  10.077846724176919
# Loss after iteration 480 :  10.077836891912225
# Loss after iteration 490 :  10.077827249522905

# %%
pred_y = x@wt
plt.scatter(range(0,len(train_y)),train_y)
plt.scatter(range(0,len(pred_y)),pred_y, color = 'r')

# %% [markdown]
# ### Predict the values on test data

# %%
x = np.empty((test_x.shape[0],test_x.shape[1]+1))
x.shape
# Out:
# (102, 14)

# %%
x[:,0] = 1
x[:,1:] = test_x[:,:]
x
# Out:
# array([[ 1.        , -0.4001727 , -0.48724019, ..., -0.25660396,
#          0.44061589, -0.34211486],
#        [ 1.        , -0.41056967, -0.48724019, ..., -1.1342242 ,
#          0.44061589, -0.31550817],
#        [ 1.        , -0.40677849,  0.37030254, ...,  0.06672981,
#          0.41936607, -0.68940216],
#        ...,
#        [ 1.        , -0.40736095, -0.48724019, ...,  1.17530274,
#          0.40282626, -0.86444617],
#        [ 1.        , -0.41352147, -0.48724019, ..., -0.3027945 ,
#          0.44061589, -1.00168066],
#        [ 1.        ,  0.74972303, -0.48724019, ...,  0.80577843,
#         -3.01598599,  0.98541887]])

# %%
pred_y = x@wt
pred_y
# Out:
# array([-2.20407064, -2.09481846, -0.54900649, -0.31559031,  0.33372503,
#         0.8541071 ,  2.52340748, -0.05871302, -0.03879226,  0.26230647,
#         0.85072318,  1.77403511,  1.40671578, -0.28241054,  4.6685162 ,
#         1.01204148, -1.12477339, -2.15786291,  1.47589807,  3.3860982 ,
#        -1.61988781,  2.48649959, -2.51269766, -1.80578997,  1.12119878,
#        -0.89762087,  0.64096585,  3.02332646,  2.27005677,  2.9459709 ,
#        -2.4444092 , -1.26799655, -0.79365424,  1.03436787, -0.72870584,
#        -1.14776506, -0.7104444 ,  2.86979078, -1.61315143,  1.06669555,
#        -0.66080405,  1.4941522 ,  2.80340843, -0.77264055,  3.19056605,
#         0.30149475, -0.78143645,  3.39081054, -0.24807621, -1.70283596,
#        -0.33656968, -0.62066746,  4.94669694, -1.01281173, -0.49001973,
#         0.25675472, -0.63134623,  1.42447227, -0.14790738,  3.38508141,
#         3.56387272,  1.80009859,  1.13516667,  0.89040215,  3.88525973,
#         2.27145373,  3.37789198, -2.00707531, -1.67560156,  4.98502039,
#         2.8226817 ,  0.64942698, -2.56199526,  1.20736071,  1.83293187,
#        -0.51176943,  2.07777472, -2.64589236, -0.16170946,  0.89063716,
#         3.62090256,  0.82399551, -1.03476966,  0.23478241, -2.62289236,
#        -0.85344936, -0.05280441, -0.2964446 , -0.7495764 , -1.64221302,
#        -0.95504891, -2.56474501, -0.0673417 ,  6.16550079,  4.50224659,
#         0.16817176,  3.51815774,  3.57154516, -0.86081756,  0.75092062,
#        -0.23308785,  2.23447399])

# %%
error = np.sqrt(np.sum(np.square(pred_y - test_y)))
error
# Out:
# 26.703359353582336

# %%
plt.scatter(range(0,len(test_y)),test_y)
plt.scatter(range(0,len(test_y)),pred_y, color = 'r')
