# %% [markdown]
# ## Customer Churn Prediction
# ### Soumyadip Payra
# ### CSE A
# ### Roll 197178

# %% [markdown]
# ### Importing Library

# %%
import pandas as pd
import numpy as np
import torch
import torch.nn as nn
import torch.nn.functional as F
from sklearn.model_selection import train_test_split
from sklearn import preprocessing
import matplotlib.pyplot as plt
import seaborn as sns
from sklearn.metrics import confusion_matrix
# %matplotlib inline

device = torch.device("cuda" if torch.cuda.is_available() else "cpu")
device
# Out:
# device(type='cuda')

# %% [markdown]
# ### Reading the Data

# %%
data = pd.read_csv("Churn_Modelling.csv")
data
# Out:
#       RowNumber  CustomerId    Surname  CreditScore Geography  Gender  Age  \
# 0             1    15634602   Hargrave          619    France  Female   42
# 1             2    15647311       Hill          608     Spain  Female   41
# 2             3    15619304       Onio          502    France  Female   42
# 3             4    15701354       Boni          699    France  Female   39
# 4             5    15737888   Mitchell          850     Spain  Female   43
# ...         ...         ...        ...          ...       ...     ...  ...
# 9995       9996    15606229   Obijiaku          771    France    Male   39
# 9996       9997    15569892  Johnstone          516    France    Male   35
# 9997       9998    15584532        Liu          709    France  Female   36
# 9998       9999    15682355  Sabbatini          772   Germany    Male   42
# 9999      10000    15628319     Walker          792    France  Female   28
#
#       Tenure    Balance  NumOfProducts  HasCrCard  IsActiveMember  \
# ...

# %% [markdown]
# ### Plotting the Data

# %%
data['Gender'].hist()
# Out:
# <AxesSubplot:>

# %%
sns.barplot(data=data,x='Exited',y='RowNumber',hue='Gender')
# Out:
# <AxesSubplot:xlabel='Exited', ylabel='RowNumber'>

# %%
data['Geography'].hist()
# Out:
# <AxesSubplot:>

# %%
sns.barplot(data=data,x='Exited',y='RowNumber',hue='Geography')
# Out:
# <AxesSubplot:xlabel='Exited', ylabel='RowNumber'>

# %%
data['NumOfProducts'].hist()
# Out:
# <AxesSubplot:>

# %%
sns.barplot(data=data,x='Exited',y='RowNumber',hue='NumOfProducts')
# Out:
# <AxesSubplot:xlabel='Exited', ylabel='RowNumber'>

# %% [markdown]
# ### Dropping unnecessary features

# %%
print("As the RowNumber, CustomerID, Surname are not important features in predicting the churing, we are dropping it")
data.drop(['RowNumber','CustomerId','Surname'],axis=1,inplace=True)
data
# Out:
# As the RowNumber, CustomerID, Surname are not important features in predicting the churing, we are dropping it
#       CreditScore Geography  Gender  Age  Tenure    Balance  NumOfProducts  \
# 0             619    France  Female   42       2       0.00              1
# 1             608     Spain  Female   41       1   83807.86              1
# 2             502    France  Female   42       8  159660.80              3
# 3             699    France  Female   39       1       0.00              2
# 4             850     Spain  Female   43       2  125510.82              1
# ...           ...       ...     ...  ...     ...        ...            ...
# 9995          771    France    Male   39       5       0.00              2
# 9996          516    France    Male   35      10   57369.61              1
# 9997          709    France  Female   36       7       0.00              1
# 9998          772   Germany    Male   42       3   75075.31              2
# ...

# %% [markdown]
# ### Segregating Dependent and Independent Variables

# %%
x = data[data.columns.drop('Exited')]
x
# Out:
#       CreditScore Geography  Gender  Age  Tenure    Balance  NumOfProducts  \
# 0             619    France  Female   42       2       0.00              1
# 1             608     Spain  Female   41       1   83807.86              1
# 2             502    France  Female   42       8  159660.80              3
# 3             699    France  Female   39       1       0.00              2
# 4             850     Spain  Female   43       2  125510.82              1
# ...           ...       ...     ...  ...     ...        ...            ...
# 9995          771    France    Male   39       5       0.00              2
# 9996          516    France    Male   35      10   57369.61              1
# 9997          709    France  Female   36       7       0.00              1
# 9998          772   Germany    Male   42       3   75075.31              2
# 9999          792    France  Female   28       4  130142.79              1
#
#       HasCrCard  IsActiveMember  EstimatedSalary
# ...

# %%
dependent_col = ['Exited']
y = torch.tensor(data[dependent_col].to_numpy()).to(device)
y.shape
# Out:
# torch.Size([10000, 1])

# %% [markdown]
# ### One hot encoding of Categorical Features

# %% [markdown]
# ### Geography

# %%
country_one_hot = pd.get_dummies(data.Geography,prefix='Geography')

# %%
x = x[x.columns.drop('Geography')]
x
# Out:
#       CreditScore  Gender  Age  Tenure    Balance  NumOfProducts  HasCrCard  \
# 0             619  Female   42       2       0.00              1          1
# 1             608  Female   41       1   83807.86              1          0
# 2             502  Female   42       8  159660.80              3          1
# 3             699  Female   39       1       0.00              2          0
# 4             850  Female   43       2  125510.82              1          1
# ...           ...     ...  ...     ...        ...            ...        ...
# 9995          771    Male   39       5       0.00              2          1
# 9996          516    Male   35      10   57369.61              1          1
# 9997          709  Female   36       7       0.00              1          0
# 9998          772    Male   42       3   75075.31              2          1
# 9999          792  Female   28       4  130142.79              1          1
#
#       IsActiveMember  EstimatedSalary
# ...

# %%
x = pd.concat([x,country_one_hot],axis=1)
x
# Out:
#       CreditScore  Gender  Age  Tenure    Balance  NumOfProducts  HasCrCard  \
# 0             619  Female   42       2       0.00              1          1
# 1             608  Female   41       1   83807.86              1          0
# 2             502  Female   42       8  159660.80              3          1
# 3             699  Female   39       1       0.00              2          0
# 4             850  Female   43       2  125510.82              1          1
# ...           ...     ...  ...     ...        ...            ...        ...
# 9995          771    Male   39       5       0.00              2          1
# 9996          516    Male   35      10   57369.61              1          1
# 9997          709  Female   36       7       0.00              1          0
# 9998          772    Male   42       3   75075.31              2          1
# 9999          792  Female   28       4  130142.79              1          1
#
# ...

# %% [markdown]
# ### Gender

# %%
gender_one_hot = pd.get_dummies(data.Gender,prefix='Gender')
gender_one_hot
# Out:
#       Gender_Female  Gender_Male
# 0                 1            0
# 1                 1            0
# 2                 1            0
# 3                 1            0
# 4                 1            0
# ...             ...          ...
# 9995              0            1
# 9996              0            1
# 9997              1            0
# 9998              0            1
# 9999              1            0
#
# [10000 rows x 2 columns]

# %%
x = x[x.columns.drop('Gender')]
x
# Out:
#       CreditScore  Age  Tenure    Balance  NumOfProducts  HasCrCard  \
# 0             619   42       2       0.00              1          1
# 1             608   41       1   83807.86              1          0
# 2             502   42       8  159660.80              3          1
# 3             699   39       1       0.00              2          0
# 4             850   43       2  125510.82              1          1
# ...           ...  ...     ...        ...            ...        ...
# 9995          771   39       5       0.00              2          1
# 9996          516   35      10   57369.61              1          1
# 9997          709   36       7       0.00              1          0
# 9998          772   42       3   75075.31              2          1
# 9999          792   28       4  130142.79              1          1
#
#       IsActiveMember  EstimatedSalary  Geography_France  Geography_Germany  \
# ...

# %%
x = pd.concat([x,gender_one_hot],axis=1)
x
# Out:
#       CreditScore  Age  Tenure    Balance  NumOfProducts  HasCrCard  \
# 0             619   42       2       0.00              1          1
# 1             608   41       1   83807.86              1          0
# 2             502   42       8  159660.80              3          1
# 3             699   39       1       0.00              2          0
# 4             850   43       2  125510.82              1          1
# ...           ...  ...     ...        ...            ...        ...
# 9995          771   39       5       0.00              2          1
# 9996          516   35      10   57369.61              1          1
# 9997          709   36       7       0.00              1          0
# 9998          772   42       3   75075.31              2          1
# 9999          792   28       4  130142.79              1          1
#
#       IsActiveMember  EstimatedSalary  Geography_France  Geography_Germany  \
# ...

# %% [markdown]
# ### Scaling of Features

# %%
scaling_col = [x.columns.drop(['HasCrCard','IsActiveMember','Geography_France', 'Geography_Germany','Geography_Spain','Gender_Female','Gender_Male'])]
scaling_col
# Out:
# [Index(['CreditScore', 'Age', 'Tenure', 'Balance', 'NumOfProducts',
#         'EstimatedSalary'],
#        dtype='object')]

# %%
scale_x = x[x.columns.drop(['HasCrCard','IsActiveMember','Geography_France', 'Geography_Germany','Geography_Spain','Gender_Female','Gender_Male'])]
scale_x
# Out:
#       CreditScore  Age  Tenure    Balance  NumOfProducts  EstimatedSalary
# 0             619   42       2       0.00              1        101348.88
# 1             608   41       1   83807.86              1        112542.58
# 2             502   42       8  159660.80              3        113931.57
# 3             699   39       1       0.00              2         93826.63
# 4             850   43       2  125510.82              1         79084.10
# ...           ...  ...     ...        ...            ...              ...
# 9995          771   39       5       0.00              2         96270.64
# 9996          516   35      10   57369.61              1        101699.77
# 9997          709   36       7       0.00              1         42085.58
# 9998          772   42       3   75075.31              2         92888.52
# 9999          792   28       4  130142.79              1         38190.78
#
# [10000 rows x 6 columns]

# %%
scaler = preprocessing.StandardScaler()
x_scaled = scaler.fit_transform(scale_x)
x_scaled
# Out:
# array([[-0.32622142,  0.29351742, -1.04175968, -1.22584767, -0.91158349,
#          0.02188649],
#        [-0.44003595,  0.19816383, -1.38753759,  0.11735002, -0.91158349,
#          0.21653375],
#        [-1.53679418,  0.29351742,  1.03290776,  1.33305335,  2.52705662,
#          0.2406869 ],
#        ...,
#        [ 0.60498839, -0.27860412,  0.68712986, -1.22584767, -0.91158349,
#         -1.00864308],
#        [ 1.25683526,  0.29351742, -0.69598177, -0.02260751,  0.80773656,
#         -0.12523071],
#        [ 1.46377078, -1.04143285, -0.35020386,  0.85996499, -0.91158349,
#         -1.07636976]])

# %%
x_scaled = pd.DataFrame(x_scaled, columns = ['CreditScore', 'Age', 'Tenure', 'Balance', 'NumOfProducts','EstimatedSalary'])
x_scaled
# Out:
#       CreditScore       Age    Tenure   Balance  NumOfProducts  \
# 0       -0.326221  0.293517 -1.041760 -1.225848      -0.911583
# 1       -0.440036  0.198164 -1.387538  0.117350      -0.911583
# 2       -1.536794  0.293517  1.032908  1.333053       2.527057
# 3        0.501521  0.007457 -1.387538 -1.225848       0.807737
# 4        2.063884  0.388871 -1.041760  0.785728      -0.911583
# ...           ...       ...       ...       ...            ...
# 9995     1.246488  0.007457 -0.004426 -1.225848       0.807737
# 9996    -1.391939 -0.373958  1.724464 -0.306379      -0.911583
# 9997     0.604988 -0.278604  0.687130 -1.225848      -0.911583
# 9998     1.256835  0.293517 -0.695982 -0.022608       0.807737
# 9999     1.463771 -1.041433 -0.350204  0.859965      -0.911583
#
#       EstimatedSalary
# 0            0.021886
# 1            0.216534
# 2            0.240687
# 3           -0.108918
# 4           -0.365276
# ...               ...
# 9995        -0.066419
# ...

# %%
x[['CreditScore', 'Age', 'Tenure', 'Balance', 'NumOfProducts','EstimatedSalary']] = x_scaled
x
# Out:
#       CreditScore       Age    Tenure   Balance  NumOfProducts  HasCrCard  \
# 0       -0.326221  0.293517 -1.041760 -1.225848      -0.911583          1
# 1       -0.440036  0.198164 -1.387538  0.117350      -0.911583          0
# 2       -1.536794  0.293517  1.032908  1.333053       2.527057          1
# 3        0.501521  0.007457 -1.387538 -1.225848       0.807737          0
# 4        2.063884  0.388871 -1.041760  0.785728      -0.911583          1
# ...           ...       ...       ...       ...            ...        ...
# 9995     1.246488  0.007457 -0.004426 -1.225848       0.807737          1
# 9996    -1.391939 -0.373958  1.724464 -0.306379      -0.911583          1
# 9997     0.604988 -0.278604  0.687130 -1.225848      -0.911583          0
# 9998     1.256835  0.293517 -0.695982 -0.022608       0.807737          1
# 9999     1.463771 -1.041433 -0.350204  0.859965      -0.911583          1
#
#       IsActiveMember  EstimatedSalary  Geography_France  Geography_Germany  \
# ...

# %% [markdown]
# ### Converting to Tensor and loading on device

# %%
x = torch.tensor(x.to_numpy(),dtype=torch.float32) ##converting to the tensor

# %%
x.to(device)
print(x.shape) #number of input nodes
# Out:
# torch.Size([10000, 13])

# %% [markdown]
# ### Splitting

# %%
train_x, test_x, train_y, test_y = train_test_split(x,y,test_size=0.3)
train_x = train_x.to(device)
test_x = test_x.to(device)
train_y = train_y.to(device)
test_y = test_y.to(device)

# %%
print("Size of train_x : {}".format(train_x.shape))
print("Size of train_y : {}".format(train_y.shape))
print("Size of test_x : {}".format(test_x.shape))
print("Size of test_y : {}".format(test_y.shape))
# Out:
# Size of train_x : torch.Size([7000, 13])
# Size of train_y : torch.Size([7000, 1])
# Size of test_x : torch.Size([3000, 13])
# Size of test_y : torch.Size([3000, 1])

# %% [markdown]
# ### Model Definition

# %%
class Net(nn.Module):
    
    def __init__(self):
        super(Net, self).__init__()
        self.fc1 = nn.Linear(13, 32) 
        self.fc2 = nn.Linear(32, 128)
#         self.fc3 = nn.Linear(128, 512)
#         self.fc4 = nn.Linear(512,128)
        self.fc5 = nn.Linear(128, 64)
        self.fc6 = nn.Linear(64, 16)
        self.fc7 = nn.Linear(16, 1)
        self.dropout = nn.Dropout(p=0.2)
        self.batchnorm1 = nn.BatchNorm1d(32)
        self.batchnorm2 = nn.BatchNorm1d(128)
        self.batchnorm5 = nn.BatchNorm1d(64)
        self.batchnorm6 = nn.BatchNorm1d(16)

    def forward(self, x):
        x = F.relu(self.fc1(x))
        x = self.batchnorm1(x)
        x = self.dropout(x)
        x = F.relu(self.fc2(x))
        x = self.batchnorm2(x)
        x = self.dropout(x)
        x = F.relu(self.fc5(x))
        x = self.batchnorm5(x)
        x = F.relu(self.fc6(x))
        x = self.batchnorm6(x)
        x = torch.sigmoid(self.fc7(x))
        return x


net = Net().to(device)

# %%
y_pred = net(train_x).to(device)
y_pred.shape
# Out:
# torch.Size([7000, 1])

# %% [markdown]
# ### Loss Function

# %%
loss_fn = nn.BCEWithLogitsLoss()
loss = loss_fn(y_pred,train_y.float())
loss
# Out:
# tensor(0.8453, device='cuda:0',
#        grad_fn=<BinaryCrossEntropyWithLogitsBackward0>)

# %% [markdown]
# ### Training Neural Network

# %% [markdown]
# ### Adam

# %%
epochs = 1200
optimizer = torch.optim.Adam(net.parameters())
Losses = []
Accuracy = []

# %%
batch_size = 32
batch_id = torch.round(torch.tensor(train_x.shape[0]/batch_size))
print("Batch Size : {} | Total Batches : {}".format(batch_size,batch_id))

# batch_idx = range(batch_id.int())[-1]
# x_batch, y_batch = train_x[batch_idx*batch_size:,:],train_y[batch_idx*batch_size:,:]
# pred_y = net(x_batch.float()).to(device)
# loss = loss_fn(pred_y,y_batch.float())
# epoch_loss = 0
# epoch_loss += loss
# epoch_loss
# y_batch.shape
# Out:
# Batch Size : 32 | Total Batches : 219.0

# %%
for epoch in range(epochs+1):
    epoch_loss = 0
    Acc = 0
    for batch_idx in range(batch_id.int()):
        if batch_idx != batch_id-1:
            x_batch = train_x[batch_idx*batch_size:(batch_idx+1)*batch_size,:].to(device)
            y_batch = train_y[batch_idx*batch_size:(batch_idx+1)*batch_size,:].to(device)
        else:
            x_batch, y_batch = train_x[batch_idx*batch_size:,:].to(device),train_y[batch_idx*batch_size:,:].to(device)
        
        pred_y = net(x_batch.float()).to(device)
        loss = loss_fn(pred_y,y_batch.float()).to(device)
        epoch_loss += loss
        pred_y_round = torch.round(pred_y)
        Acc += (pred_y_round == y_batch).sum().float()/y_batch.shape[0]
        
        optimizer.zero_grad()
        loss.backward()
        optimizer.step()
        
    Losses.append(epoch_loss)
    Accuracy.append(Acc/batch_id)
    if epoch%10 == 0:
        print("Epoch : {} \t| loss : {} \t| accuracy : {}".format(epoch,epoch_loss/batch_id,Acc/batch_id))
# Out:
# Epoch : 1010 	| loss : 0.657690167427063 	| accuracy : 0.8924086093902588
# Epoch : 1020 	| loss : 0.6556468605995178 	| accuracy : 0.8974029421806335
# Epoch : 1030 	| loss : 0.6550971865653992 	| accuracy : 0.8975456357002258
# Epoch : 1040 	| loss : 0.6538735032081604 	| accuracy : 0.9006848931312561
# Epoch : 1050 	| loss : 0.653392493724823 	| accuracy : 0.902111828327179
# Epoch : 1060 	| loss : 0.6536285281181335 	| accuracy : 0.901112973690033
# Epoch : 1070 	| loss : 0.6523328423500061 	| accuracy : 0.9046803116798401
# Epoch : 1080 	| loss : 0.6534363031387329 	| accuracy : 0.9012556672096252
# Epoch : 1090 	| loss : 0.651646614074707 	| accuracy : 0.9061072468757629
# Epoch : 1100 	| loss : 0.6511988043785095 	| accuracy : 0.9069634079933167
# Epoch : 1110 	| loss : 0.6519777774810791 	| accuracy : 0.9049656987190247
# Epoch : 1120 	| loss : 0.6507528424263 	| accuracy : 0.9078195691108704
# Epoch : 1130 	| loss : 0.6512082815170288 	| accuracy : 0.9072487950325012
# ...

# %% [markdown]
# ### Test Data

# %%
net.eval()
with torch.no_grad():
    pred_y_test = torch.round(net(test_x.float()))
    loss = loss_fn(pred_y_test,test_y.float())
    Acc = (pred_y_test == test_y).sum().float()/test_y.shape[0]
    print("On Testing Data ==> \t loss : {} \t| accuracy : {}".format(loss,Acc))
# Out:
# On Testing Data ==> 	 loss : 0.6792760491371155 	| accuracy : 0.8666666746139526

# %%
plt.plot(range(1,epochs+1),[Loss.cpu().detach().numpy() for Loss in Losses])

# %%
plt.plot(range(1,epochs+1),[Acc.cpu().detach().numpy() for Acc in Accuracy],c='orange')

# %% [markdown]
# ### Confusion Matrix

# %%
confusion_matrix(pred_y_test.cpu(),test_y.float().cpu())
# Out:
# array([[2306,  287],
#        [ 113,  294]], dtype=int64)

# %%
tn, fp, fn, tp = confusion_matrix(pred_y_test.cpu(),test_y.float().cpu()).ravel()
print('True Negatives : {}'.format(tn))
print('False Negatives : {}'.format(fn))
print('True Positives : {}'.format(tp))
print('False Positives : {}'.format(fp))
# Out:
# True Negatives : 2306
# False Negatives : 113
# True Positives : 294
# False Positives : 287

# %% [markdown]
# ### Thank You
